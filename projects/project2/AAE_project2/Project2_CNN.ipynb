# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext lab_black
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf


from keras.callbacks import Callback
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    LearningRateScheduler,
    ReduceLROnPlateau,
    EarlyStopping,
    TensorBoard,
)
from tensorflow.keras import backend as K
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras.regularizers import l2
from tensorflow.compat.v2.keras.layers import BatchNormalization
from tensorflow.python.client import device_lib
from utils import *
from models.cnn import *
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(8)
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1089228082820436400
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4937233203
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17981811758123211977
# physical_device_desc: "device: 0, name: GeForce GTX 1060 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Loading images

# %%
image_dir_train = "data/training/images/"
files = os.listdir(image_dir_train)
n_train = len(files)
print(f"Loading training images, images loaded: {n_train} ")
imgs_train = np.asarray([load_img(image_dir_train + files[i]) for i in range(n_train)])
gt_dir_train = "data/training/groundtruth/"
print(f"Loading groundtruth images, images loaded: {n_train} ")
gt_imgs_train = np.asarray([load_img(gt_dir_train + files[i]) for i in range(n_train)])
# Out:
# Loading training images, images loaded: 100
# Loading groundtruth images, images loaded: 100

# %%
X_train, Y_train = imag_rotation_aug(imgs_train, gt_imgs_train)

# %%
X_train = np.asarray(X_train)
Y_train = np.asarray(Y_train)

# %%
print(X_train.shape)
print(Y_train.shape)
n_train = Y_train.shape[0]
# Out:
# (900, 448, 448, 3)
# (900, 448, 448)

# %%
# We define parameters of the model
BATCH_SIZE = 300
WINDOW_SIZE = 64
PATCH_SIZE = 16
EPOCHS = 200
STEPS_PER_EPOCH = 100
WIDTH = 448
model = CNN(
    shape=(WINDOW_SIZE, WINDOW_SIZE, 3),
    BATCH_SIZE=BATCH_SIZE,
    WINDOW_SIZE=WINDOW_SIZE,
    PATCH_SIZE=PATCH_SIZE,
    EPOCHS=EPOCHS,
    STEPS_PER_EPOCH=STEPS_PER_EPOCH,
    WIDTH=WIDTH,
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 64)        4864
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 1024)        4719616
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 1024)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 1024)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation (Activation)      (None, 2)                 0
# =================================================================
# Total params: 6,798,338
# Trainable params: 6,798,338
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.train(X_train, Y_train, n_train)
model.save("best_cnn.h5")
# Out:
# Epoch 1/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.5465 - accuracy: 0.7556 - recall: 0.7518 - f1: 0.7518
# Epoch 00001: loss improved from inf to 0.54624, saving model to saved_models/CNN_dropout_0.25_1024-001-0.751792.h5
# 100/100 [==============================] - 40s 401ms/step - loss: 0.5462 - accuracy: 0.7556 - recall: 0.7518 - f1: 0.7518
# Epoch 2/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.5072 - accuracy: 0.7543 - recall: 0.7540 - f1: 0.7542
# Epoch 00002: loss improved from 0.54624 to 0.50715, saving model to saved_models/CNN_dropout_0.25_1024-002-0.753957.h5
# 100/100 [==============================] - 35s 347ms/step - loss: 0.5072 - accuracy: 0.7540 - recall: 0.7538 - f1: 0.7540
# Epoch 3/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.4692 - accuracy: 0.7686 - recall: 0.7702 - f1: 0.7690
# Epoch 00003: loss improved from 0.50715 to 0.46877, saving model to saved_models/CNN_dropout_0.25_1024-003-0.769239.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.4688 - accuracy: 0.7689 - recall: 0.7705 - f1: 0.7692
# Epoch 4/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.4666 - accuracy: 0.7737 - recall: 0.7745 - f1: 0.7739
# Epoch 00004: loss improved from 0.46877 to 0.46661, saving model to saved_models/CNN_dropout_0.25_1024-004-0.774179.h5
# 100/100 [==============================] - 35s 349ms/step - loss: 0.4666 - accuracy: 0.7740 - recall: 0.7748 - f1: 0.7742
# Epoch 5/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.4320 - accuracy: 0.7942 - recall: 0.7953 - f1: 0.7944
# Epoch 00005: loss improved from 0.46661 to 0.43169, saving model to saved_models/CNN_dropout_0.25_1024-005-0.794467.h5
# 100/100 [==============================] - 36s 362ms/step - loss: 0.4317 - accuracy: 0.7943 - recall: 0.7953 - f1: 0.7945
# Epoch 6/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.4128 - accuracy: 0.8071 - recall: 0.8081 - f1: 0.8073
# Epoch 00006: loss improved from 0.43169 to 0.41242, saving model to saved_models/CNN_dropout_0.25_1024-006-0.807287.h5
# 100/100 [==============================] - 36s 360ms/step - loss: 0.4124 - accuracy: 0.8071 - recall: 0.8080 - f1: 0.8073
# Epoch 7/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.3479 - accuracy: 0.8441 - recall: 0.8453 - f1: 0.8442
# Epoch 00007: loss improved from 0.41242 to 0.34736, saving model to saved_models/CNN_dropout_0.25_1024-007-0.844323.h5
# 100/100 [==============================] - 37s 366ms/step - loss: 0.3474 - accuracy: 0.8442 - recall: 0.8453 - f1: 0.8443
# Epoch 8/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.3239 - accuracy: 0.8545 - recall: 0.8548 - f1: 0.8545
# Epoch 00008: loss improved from 0.34736 to 0.32353, saving model to saved_models/CNN_dropout_0.25_1024-008-0.854832.h5
# 100/100 [==============================] - 36s 357ms/step - loss: 0.3235 - accuracy: 0.8548 - recall: 0.8552 - f1: 0.8548
# Epoch 9/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.3054 - accuracy: 0.8652 - recall: 0.8661 - f1: 0.8653
# Epoch 00009: loss improved from 0.32353 to 0.30528, saving model to saved_models/CNN_dropout_0.25_1024-009-0.865285.h5
# 100/100 [==============================] - 36s 362ms/step - loss: 0.3053 - accuracy: 0.8652 - recall: 0.8661 - f1: 0.8653
# Epoch 10/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2892 - accuracy: 0.8732 - recall: 0.8732 - f1: 0.8732
# Epoch 00010: loss improved from 0.30528 to 0.28897, saving model to saved_models/CNN_dropout_0.25_1024-010-0.873454.h5
# 100/100 [==============================] - 37s 369ms/step - loss: 0.2890 - accuracy: 0.8734 - recall: 0.8734 - f1: 0.8735
# Epoch 11/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2803 - accuracy: 0.8776 - recall: 0.8772 - f1: 0.8776
# Epoch 00011: loss improved from 0.28897 to 0.28020, saving model to saved_models/CNN_dropout_0.25_1024-011-0.877708.h5
# 100/100 [==============================] - 37s 369ms/step - loss: 0.2802 - accuracy: 0.8778 - recall: 0.8773 - f1: 0.8777
# Epoch 12/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2688 - accuracy: 0.8846 - recall: 0.8851 - f1: 0.8846
# Epoch 00012: loss improved from 0.28020 to 0.26920, saving model to saved_models/CNN_dropout_0.25_1024-012-0.884523.h5
# 100/100 [==============================] - 40s 401ms/step - loss: 0.2692 - accuracy: 0.8845 - recall: 0.8849 - f1: 0.8845
# Epoch 13/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2591 - accuracy: 0.8872 - recall: 0.8875 - f1: 0.8872
# Epoch 00013: loss improved from 0.26920 to 0.25904, saving model to saved_models/CNN_dropout_0.25_1024-013-0.887113.h5
# 100/100 [==============================] - 39s 393ms/step - loss: 0.2590 - accuracy: 0.8871 - recall: 0.8874 - f1: 0.8871
# Epoch 14/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2517 - accuracy: 0.8914 - recall: 0.8918 - f1: 0.8915
# Epoch 00014: loss improved from 0.25904 to 0.25201, saving model to saved_models/CNN_dropout_0.25_1024-014-0.891225.h5
# 100/100 [==============================] - 36s 364ms/step - loss: 0.2520 - accuracy: 0.8912 - recall: 0.8915 - f1: 0.8912
# Epoch 15/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2469 - accuracy: 0.8930 - recall: 0.8930 - f1: 0.8930
# Epoch 00015: loss improved from 0.25201 to 0.24645, saving model to saved_models/CNN_dropout_0.25_1024-015-0.893262.h5
# 100/100 [==============================] - 37s 373ms/step - loss: 0.2465 - accuracy: 0.8933 - recall: 0.8933 - f1: 0.8933
# Epoch 16/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2353 - accuracy: 0.9002 - recall: 0.9000 - f1: 0.9002
# Epoch 00016: loss improved from 0.24645 to 0.23492, saving model to saved_models/CNN_dropout_0.25_1024-016-0.900450.h5
# 100/100 [==============================] - 35s 345ms/step - loss: 0.2349 - accuracy: 0.9005 - recall: 0.9003 - f1: 0.9004
# Epoch 17/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2274 - accuracy: 0.9027 - recall: 0.9026 - f1: 0.9027
# Epoch 00017: loss improved from 0.23492 to 0.22751, saving model to saved_models/CNN_dropout_0.25_1024-017-0.902837.h5
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2275 - accuracy: 0.9028 - recall: 0.9027 - f1: 0.9028
# Epoch 18/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2301 - accuracy: 0.9037 - recall: 0.9039 - f1: 0.9037
# Epoch 00018: loss did not improve from 0.22751
# 100/100 [==============================] - 34s 341ms/step - loss: 0.2299 - accuracy: 0.9037 - recall: 0.9039 - f1: 0.9038
# Epoch 19/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2166 - accuracy: 0.9097 - recall: 0.9108 - f1: 0.9098
# Epoch 00019: loss improved from 0.22751 to 0.21655, saving model to saved_models/CNN_dropout_0.25_1024-019-0.909783.h5
# 100/100 [==============================] - 34s 345ms/step - loss: 0.2166 - accuracy: 0.9097 - recall: 0.9108 - f1: 0.9098
# Epoch 20/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2311 - accuracy: 0.9026 - recall: 0.9028 - f1: 0.9026
# Epoch 00020: loss did not improve from 0.21655
# 100/100 [==============================] - 34s 341ms/step - loss: 0.2310 - accuracy: 0.9027 - recall: 0.9029 - f1: 0.9027
# Epoch 21/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2084 - accuracy: 0.9138 - recall: 0.9141 - f1: 0.9138
# Epoch 00021: loss improved from 0.21655 to 0.20861, saving model to saved_models/CNN_dropout_0.25_1024-021-0.913869.h5
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2086 - accuracy: 0.9139 - recall: 0.9141 - f1: 0.9139
# Epoch 22/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9145 - recall: 0.9147 - f1: 0.9145
# Epoch 00022: loss improved from 0.20861 to 0.20543, saving model to saved_models/CNN_dropout_0.25_1024-022-0.914334.h5
# 100/100 [==============================] - 35s 345ms/step - loss: 0.2054 - accuracy: 0.9143 - recall: 0.9146 - f1: 0.9143
# Epoch 23/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2088 - accuracy: 0.9140 - recall: 0.9136 - f1: 0.9140
# Epoch 00023: loss did not improve from 0.20543
# 100/100 [==============================] - 34s 341ms/step - loss: 0.2084 - accuracy: 0.9143 - recall: 0.9139 - f1: 0.9143
# Epoch 24/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9173 - recall: 0.9173 - f1: 0.9173
# Epoch 00024: loss improved from 0.20543 to 0.19939, saving model to saved_models/CNN_dropout_0.25_1024-024-0.917299.h5
# 100/100 [==============================] - 35s 347ms/step - loss: 0.1994 - accuracy: 0.9173 - recall: 0.9173 - f1: 0.9173
# Epoch 25/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1998 - accuracy: 0.9177 - recall: 0.9175 - f1: 0.9177
# Epoch 00025: loss did not improve from 0.19939
# 100/100 [==============================] - 34s 341ms/step - loss: 0.1995 - accuracy: 0.9178 - recall: 0.9176 - f1: 0.9178
# Epoch 26/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9198 - recall: 0.9202 - f1: 0.9198
# Epoch 00026: loss improved from 0.19939 to 0.19769, saving model to saved_models/CNN_dropout_0.25_1024-026-0.919814.h5
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1977 - accuracy: 0.9198 - recall: 0.9201 - f1: 0.9198
# Epoch 27/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.9160 - recall: 0.9160 - f1: 0.9160
# Epoch 00027: loss did not improve from 0.19769
# 100/100 [==============================] - 36s 359ms/step - loss: 0.2057 - accuracy: 0.9161 - recall: 0.9161 - f1: 0.9161
# Epoch 28/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.2012 - accuracy: 0.9161 - recall: 0.9162 - f1: 0.9161
# Epoch 00028: loss did not improve from 0.19769
# 100/100 [==============================] - 42s 423ms/step - loss: 0.2010 - accuracy: 0.9161 - recall: 0.9162 - f1: 0.9161
# Epoch 29/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9223 - recall: 0.9222 - f1: 0.9223
# Epoch 00029: loss improved from 0.19769 to 0.18992, saving model to saved_models/CNN_dropout_0.25_1024-029-0.922291.h5
# 100/100 [==============================] - 44s 440ms/step - loss: 0.1899 - accuracy: 0.9223 - recall: 0.9222 - f1: 0.9223
# Epoch 30/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1902 - accuracy: 0.9205 - recall: 0.9205 - f1: 0.9205
# Epoch 00030: loss improved from 0.18992 to 0.18990, saving model to saved_models/CNN_dropout_0.25_1024-030-0.920598.h5
# 100/100 [==============================] - 38s 376ms/step - loss: 0.1899 - accuracy: 0.9206 - recall: 0.9206 - f1: 0.9206
# Epoch 31/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1894 - accuracy: 0.9226 - recall: 0.9227 - f1: 0.9226
# Epoch 00031: loss improved from 0.18990 to 0.18948, saving model to saved_models/CNN_dropout_0.25_1024-031-0.922388.h5
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1895 - accuracy: 0.9224 - recall: 0.9224 - f1: 0.9224
# Epoch 32/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.9227 - recall: 0.9230 - f1: 0.9227
# Epoch 00032: loss did not improve from 0.18948
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1901 - accuracy: 0.9226 - recall: 0.9228 - f1: 0.9226
# Epoch 33/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1833 - accuracy: 0.9264 - recall: 0.9267 - f1: 0.9265
# Epoch 00033: loss improved from 0.18948 to 0.18287, saving model to saved_models/CNN_dropout_0.25_1024-033-0.926703.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1829 - accuracy: 0.9267 - recall: 0.9269 - f1: 0.9267
# Epoch 34/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9251 - recall: 0.9249 - f1: 0.9250
# Epoch 00034: loss improved from 0.18287 to 0.18157, saving model to saved_models/CNN_dropout_0.25_1024-034-0.925152.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1816 - accuracy: 0.9252 - recall: 0.9250 - f1: 0.9252
# Epoch 35/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9255 - recall: 0.9255 - f1: 0.9255
# Epoch 00035: loss did not improve from 0.18157
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1826 - accuracy: 0.9256 - recall: 0.9255 - f1: 0.9256
# Epoch 36/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1766 - accuracy: 0.9271 - recall: 0.9269 - f1: 0.9271
# Epoch 00036: loss improved from 0.18157 to 0.17603, saving model to saved_models/CNN_dropout_0.25_1024-036-0.927413.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1760 - accuracy: 0.9274 - recall: 0.9272 - f1: 0.9274
# Epoch 37/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1870 - accuracy: 0.9236 - recall: 0.9235 - f1: 0.9235
# Epoch 00037: loss did not improve from 0.17603
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1867 - accuracy: 0.9237 - recall: 0.9236 - f1: 0.9237
# Epoch 38/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1780 - accuracy: 0.9256 - recall: 0.9254 - f1: 0.9256
# Epoch 00038: loss did not improve from 0.17603
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1780 - accuracy: 0.9258 - recall: 0.9256 - f1: 0.9258
# Epoch 39/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9280 - recall: 0.9277 - f1: 0.9280
# Epoch 00039: loss did not improve from 0.17603
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1806 - accuracy: 0.9278 - recall: 0.9275 - f1: 0.9278
# Epoch 40/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9260 - recall: 0.9258 - f1: 0.9260
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00040: loss did not improve from 0.17603
# 100/100 [==============================] - 35s 346ms/step - loss: 0.1809 - accuracy: 0.9257 - recall: 0.9254 - f1: 0.9256
# Epoch 41/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1686 - accuracy: 0.9297 - recall: 0.9295 - f1: 0.9297
# Epoch 00041: loss improved from 0.17603 to 0.16824, saving model to saved_models/CNN_dropout_0.25_1024-041-0.929802.h5
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1682 - accuracy: 0.9298 - recall: 0.9296 - f1: 0.9298
# Epoch 42/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1521 - accuracy: 0.9382 - recall: 0.9381 - f1: 0.9382
# Epoch 00042: loss improved from 0.16824 to 0.15208, saving model to saved_models/CNN_dropout_0.25_1024-042-0.938063.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1521 - accuracy: 0.9381 - recall: 0.9380 - f1: 0.9381
# Epoch 43/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9385 - recall: 0.9383 - f1: 0.9385
# Epoch 00043: loss did not improve from 0.15208
# 100/100 [==============================] - 35s 346ms/step - loss: 0.1550 - accuracy: 0.9384 - recall: 0.9382 - f1: 0.9384
# Epoch 44/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1547 - accuracy: 0.9388 - recall: 0.9386 - f1: 0.9387
# Epoch 00044: loss did not improve from 0.15208
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1548 - accuracy: 0.9387 - recall: 0.9385 - f1: 0.9387
# Epoch 45/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9436 - recall: 0.9433 - f1: 0.9436
# Epoch 00045: loss improved from 0.15208 to 0.14247, saving model to saved_models/CNN_dropout_0.25_1024-045-0.943650.h5
# 100/100 [==============================] - 35s 347ms/step - loss: 0.1425 - accuracy: 0.9437 - recall: 0.9434 - f1: 0.9436
# Epoch 46/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9409 - recall: 0.9407 - f1: 0.9409
# Epoch 00046: loss did not improve from 0.14247
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1491 - accuracy: 0.9410 - recall: 0.9408 - f1: 0.9410
# Epoch 47/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1470 - accuracy: 0.9404 - recall: 0.9403 - f1: 0.9404
# Epoch 00047: loss did not improve from 0.14247
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1469 - accuracy: 0.9404 - recall: 0.9403 - f1: 0.9404
# Epoch 48/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9403 - recall: 0.9402 - f1: 0.9403
# Epoch 00048: loss did not improve from 0.14247
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1488 - accuracy: 0.9402 - recall: 0.9402 - f1: 0.9402
# Epoch 49/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1481 - accuracy: 0.9400 - recall: 0.9399 - f1: 0.9400
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00049: loss did not improve from 0.14247
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1485 - accuracy: 0.9398 - recall: 0.9397 - f1: 0.9398
# Epoch 50/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1400 - accuracy: 0.9453 - recall: 0.9453 - f1: 0.9453
# Epoch 00050: loss improved from 0.14247 to 0.14032, saving model to saved_models/CNN_dropout_0.25_1024-050-0.945112.h5
# 100/100 [==============================] - 35s 349ms/step - loss: 0.1403 - accuracy: 0.9451 - recall: 0.9450 - f1: 0.9451
# Epoch 51/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9452 - recall: 0.9448 - f1: 0.9452
# Epoch 00051: loss improved from 0.14032 to 0.13521, saving model to saved_models/CNN_dropout_0.25_1024-051-0.945226.h5
# 100/100 [==============================] - 35s 347ms/step - loss: 0.1352 - accuracy: 0.9452 - recall: 0.9449 - f1: 0.9452
# Epoch 52/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9479 - recall: 0.9477 - f1: 0.9479
# Epoch 00052: loss improved from 0.13521 to 0.12888, saving model to saved_models/CNN_dropout_0.25_1024-052-0.948007.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1289 - accuracy: 0.9480 - recall: 0.9478 - f1: 0.9480
# Epoch 53/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9464 - recall: 0.9462 - f1: 0.9464
# Epoch 00053: loss did not improve from 0.12888
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1323 - accuracy: 0.9465 - recall: 0.9464 - f1: 0.9465
# Epoch 54/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9449 - recall: 0.9447 - f1: 0.9449
# Epoch 00054: loss did not improve from 0.12888
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1329 - accuracy: 0.9449 - recall: 0.9447 - f1: 0.9449
# Epoch 55/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1306 - accuracy: 0.9460 - recall: 0.9459 - f1: 0.9460
# Epoch 00055: loss did not improve from 0.12888
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1308 - accuracy: 0.9459 - recall: 0.9457 - f1: 0.9459
# Epoch 56/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9481 - recall: 0.9479 - f1: 0.9481
# Epoch 00056: loss improved from 0.12888 to 0.12775, saving model to saved_models/CNN_dropout_0.25_1024-056-0.947883.h5
# 100/100 [==============================] - 35s 352ms/step - loss: 0.1278 - accuracy: 0.9479 - recall: 0.9476 - f1: 0.9479
# Epoch 57/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1335 - accuracy: 0.9459 - recall: 0.9456 - f1: 0.9458
# Epoch 00057: loss did not improve from 0.12775
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1336 - accuracy: 0.9457 - recall: 0.9454 - f1: 0.9457
# Epoch 58/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9513 - recall: 0.9509 - f1: 0.9512
# Epoch 00058: loss improved from 0.12775 to 0.12432, saving model to saved_models/CNN_dropout_0.25_1024-058-0.950966.h5
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1243 - accuracy: 0.9510 - recall: 0.9507 - f1: 0.9510
# Epoch 59/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9496 - recall: 0.9493 - f1: 0.9496
# Epoch 00059: loss did not improve from 0.12432
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1262 - accuracy: 0.9495 - recall: 0.9493 - f1: 0.9495
# Epoch 60/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1285 - accuracy: 0.9484 - recall: 0.9484 - f1: 0.9484
# Epoch 00060: loss did not improve from 0.12432
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1285 - accuracy: 0.9484 - recall: 0.9483 - f1: 0.9484
# Epoch 61/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9473 - recall: 0.9471 - f1: 0.9472
# Epoch 00061: loss did not improve from 0.12432
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1316 - accuracy: 0.9470 - recall: 0.9469 - f1: 0.9470
# Epoch 62/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9499 - recall: 0.9499 - f1: 0.9499
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00062: loss did not improve from 0.12432
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1261 - accuracy: 0.9501 - recall: 0.9501 - f1: 0.9501
# Epoch 63/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1194 - accuracy: 0.9534 - recall: 0.9533 - f1: 0.9534
# Epoch 00063: loss improved from 0.12432 to 0.11930, saving model to saved_models/CNN_dropout_0.25_1024-063-0.953312.h5
# 100/100 [==============================] - 35s 350ms/step - loss: 0.1193 - accuracy: 0.9533 - recall: 0.9532 - f1: 0.9533
# Epoch 64/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9528 - recall: 0.9528 - f1: 0.9528
# Epoch 00064: loss improved from 0.11930 to 0.11708, saving model to saved_models/CNN_dropout_0.25_1024-064-0.952730.h5
# 100/100 [==============================] - 35s 349ms/step - loss: 0.1171 - accuracy: 0.9527 - recall: 0.9527 - f1: 0.9527
# Epoch 65/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1199 - accuracy: 0.9504 - recall: 0.9503 - f1: 0.9504
# Epoch 00065: loss did not improve from 0.11708
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1195 - accuracy: 0.9506 - recall: 0.9505 - f1: 0.9506
# Epoch 66/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1195 - accuracy: 0.9509 - recall: 0.9508 - f1: 0.9509
# Epoch 00066: loss did not improve from 0.11708
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1196 - accuracy: 0.9510 - recall: 0.9509 - f1: 0.9510
# Epoch 67/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1223 - accuracy: 0.9499 - recall: 0.9497 - f1: 0.9499
# Epoch 00067: loss did not improve from 0.11708
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1222 - accuracy: 0.9499 - recall: 0.9498 - f1: 0.9499
# Epoch 68/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9531 - recall: 0.9530 - f1: 0.9531
# Epoch 00068: loss improved from 0.11708 to 0.11684, saving model to saved_models/CNN_dropout_0.25_1024-068-0.952960.h5
# 100/100 [==============================] - 35s 351ms/step - loss: 0.1168 - accuracy: 0.9530 - recall: 0.9528 - f1: 0.9530
# Epoch 69/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9516 - recall: 0.9517 - f1: 0.9516
# Epoch 00069: loss did not improve from 0.11684
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1183 - accuracy: 0.9516 - recall: 0.9517 - f1: 0.9516
# Epoch 70/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1190 - accuracy: 0.9513 - recall: 0.9512 - f1: 0.9513
# Epoch 00070: loss did not improve from 0.11684
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1192 - accuracy: 0.9512 - recall: 0.9511 - f1: 0.9512
# Epoch 71/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9531 - recall: 0.9529 - f1: 0.9531
# Epoch 00071: loss did not improve from 0.11684
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1172 - accuracy: 0.9530 - recall: 0.9528 - f1: 0.9530
# Epoch 72/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9549 - recall: 0.9549 - f1: 0.9549
# Epoch 00072: loss improved from 0.11684 to 0.11318, saving model to saved_models/CNN_dropout_0.25_1024-072-0.954899.h5
# 100/100 [==============================] - 35s 350ms/step - loss: 0.1132 - accuracy: 0.9549 - recall: 0.9549 - f1: 0.9549
# Epoch 73/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1166 - accuracy: 0.9535 - recall: 0.9534 - f1: 0.9535
# Epoch 00073: loss did not improve from 0.11318
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1168 - accuracy: 0.9534 - recall: 0.9533 - f1: 0.9534
# Epoch 74/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9545 - recall: 0.9545 - f1: 0.9545
# Epoch 00074: loss did not improve from 0.11318
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1161 - accuracy: 0.9544 - recall: 0.9543 - f1: 0.9544
# Epoch 75/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9526 - recall: 0.9526 - f1: 0.9526
# Epoch 00075: loss did not improve from 0.11318
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1160 - accuracy: 0.9525 - recall: 0.9525 - f1: 0.9525
# Epoch 76/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9521 - recall: 0.9519 - f1: 0.9521
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00076: loss did not improve from 0.11318
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1156 - accuracy: 0.9520 - recall: 0.9519 - f1: 0.9520
# Epoch 77/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1094 - accuracy: 0.9561 - recall: 0.9561 - f1: 0.9561
# Epoch 00077: loss improved from 0.11318 to 0.10942, saving model to saved_models/CNN_dropout_0.25_1024-077-0.956014.h5
# 100/100 [==============================] - 35s 350ms/step - loss: 0.1094 - accuracy: 0.9560 - recall: 0.9560 - f1: 0.9560
# Epoch 78/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9536 - recall: 0.9533 - f1: 0.9535
# Epoch 00078: loss did not improve from 0.10942
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1170 - accuracy: 0.9535 - recall: 0.9532 - f1: 0.9534
# Epoch 79/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9561 - recall: 0.9560 - f1: 0.9561
# Epoch 00079: loss did not improve from 0.10942
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1101 - accuracy: 0.9561 - recall: 0.9560 - f1: 0.9561
# Epoch 80/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9532 - recall: 0.9532 - f1: 0.9532
# Epoch 00080: loss did not improve from 0.10942
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1152 - accuracy: 0.9532 - recall: 0.9532 - f1: 0.9532
# Epoch 81/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1129 - accuracy: 0.9562 - recall: 0.9562 - f1: 0.9562
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00081: loss did not improve from 0.10942
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1128 - accuracy: 0.9564 - recall: 0.9563 - f1: 0.9563
# Epoch 82/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9568 - recall: 0.9568 - f1: 0.9568
# Epoch 00082: loss improved from 0.10942 to 0.10918, saving model to saved_models/CNN_dropout_0.25_1024-082-0.956814.h5
# 100/100 [==============================] - 35s 349ms/step - loss: 0.1092 - accuracy: 0.9568 - recall: 0.9568 - f1: 0.9568
# Epoch 83/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9561 - recall: 0.9563 - f1: 0.9561
# Epoch 00083: loss improved from 0.10918 to 0.10781, saving model to saved_models/CNN_dropout_0.25_1024-083-0.956288.h5
# 100/100 [==============================] - 35s 347ms/step - loss: 0.1078 - accuracy: 0.9563 - recall: 0.9564 - f1: 0.9563
# Epoch 84/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9542 - recall: 0.9542 - f1: 0.9542
# Epoch 00084: loss did not improve from 0.10781
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1099 - accuracy: 0.9543 - recall: 0.9543 - f1: 0.9543
# Epoch 85/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9544 - recall: 0.9542 - f1: 0.9544
# Epoch 00085: loss did not improve from 0.10781
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1093 - accuracy: 0.9543 - recall: 0.9541 - f1: 0.9543
# Epoch 86/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9569 - recall: 0.9569 - f1: 0.9569
# Epoch 00086: loss improved from 0.10781 to 0.10768, saving model to saved_models/CNN_dropout_0.25_1024-086-0.956931.h5
# 100/100 [==============================] - 35s 352ms/step - loss: 0.1077 - accuracy: 0.9569 - recall: 0.9569 - f1: 0.9569
# Epoch 87/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9573 - recall: 0.9573 - f1: 0.9573
# Epoch 00087: loss improved from 0.10768 to 0.10718, saving model to saved_models/CNN_dropout_0.25_1024-087-0.957452.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1072 - accuracy: 0.9574 - recall: 0.9575 - f1: 0.9575
# Epoch 88/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9592 - recall: 0.9592 - f1: 0.9592
# Epoch 00088: loss improved from 0.10718 to 0.10385, saving model to saved_models/CNN_dropout_0.25_1024-088-0.959252.h5
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1039 - accuracy: 0.9592 - recall: 0.9593 - f1: 0.9593
# Epoch 89/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9581 - recall: 0.9582 - f1: 0.9581
# Epoch 00089: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1054 - accuracy: 0.9583 - recall: 0.9584 - f1: 0.9583
# Epoch 90/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9560 - recall: 0.9559 - f1: 0.9560
# Epoch 00090: loss did not improve from 0.10385
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1082 - accuracy: 0.9560 - recall: 0.9559 - f1: 0.9560
# Epoch 91/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9574 - recall: 0.9574 - f1: 0.9574
# Epoch 00091: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1059 - accuracy: 0.9574 - recall: 0.9575 - f1: 0.9575
# Epoch 92/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9573 - recall: 0.9572 - f1: 0.9573
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00092: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 346ms/step - loss: 0.1080 - accuracy: 0.9572 - recall: 0.9571 - f1: 0.9572
# Epoch 93/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9565 - recall: 0.9565 - f1: 0.9565
# Epoch 00093: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1092 - accuracy: 0.9566 - recall: 0.9566 - f1: 0.9566
# Epoch 94/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9576 - recall: 0.9576 - f1: 0.9576
# Epoch 00094: loss did not improve from 0.10385
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1065 - accuracy: 0.9574 - recall: 0.9575 - f1: 0.9574
# Epoch 95/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1105 - accuracy: 0.9546 - recall: 0.9547 - f1: 0.9546
# Epoch 00095: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 346ms/step - loss: 0.1104 - accuracy: 0.9546 - recall: 0.9546 - f1: 0.9546
# Epoch 96/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1069 - accuracy: 0.9564 - recall: 0.9563 - f1: 0.9564
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00096: loss did not improve from 0.10385
# 100/100 [==============================] - 35s 346ms/step - loss: 0.1069 - accuracy: 0.9563 - recall: 0.9562 - f1: 0.9563
# Epoch 97/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9570 - recall: 0.9571 - f1: 0.9570
# Epoch 00097: loss did not improve from 0.10385
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1063 - accuracy: 0.9569 - recall: 0.9570 - f1: 0.9569
# Epoch 98/200
#  99/100 [============================>.] - ETA: 0s - loss: 0.1062 - accuracy: 0.9584 - recall: 0.9583 - f1: 0.9583
# Epoch 00098: loss did not improve from 0.10385
# Restoring model weights from the end of the best epoch.
# 100/100 [==============================] - 35s 345ms/step - loss: 0.1063 - accuracy: 0.9584 - recall: 0.9584 - f1: 0.9584
# Epoch 00098: early stopping

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure(figsize=(15, 10))
plt.plot(history.history["loss"][1:], label="train_loss")
plt.plot(history.history["accuracy"][1:], label="train_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plots/CNN_dropout_0.25_1024.pdf")
plt.show()

# %%
model = CNN(
    shape=(WINDOW_SIZE, WINDOW_SIZE, 3),
    BATCH_SIZE=BATCH_SIZE,
    WINDOW_SIZE=WINDOW_SIZE,
    PATCH_SIZE=PATCH_SIZE,
    EPOCHS=EPOCHS,
    STEPS_PER_EPOCH=STEPS_PER_EPOCH,
    WIDTH=WIDTH,
)
model.load("best_cnn.h5")
image_filenames = []
for i in range(1, 51):
    image_filename = "data/test_set_images/test_" + str(i) + "/test_" + str(i) + ".png"
    image_filenames.append(image_filename)

submission_filename = "best_cnn.csv"
generate_submission(model, submission_filename, *image_filenames)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 64, 64, 64)        4864
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 1024)        4719616
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 4, 4, 1024)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 1024)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 1024)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               524416
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 6,798,338
# Trainable params: 6,798,338
# Non-trainable params: 0
# _________________________________________________________________
# Generating predictions for image:  data/test_set_images/test_1/test_1.png
# Generating predictions for image:  data/test_set_images/test_2/test_2.png
# Generating predictions for image:  data/test_set_images/test_3/test_3.png
# Generating predictions for image:  data/test_set_images/test_4/test_4.png
# Generating predictions for image:  data/test_set_images/test_5/test_5.png
# Generating predictions for image:  data/test_set_images/test_6/test_6.png
# Generating predictions for image:  data/test_set_images/test_7/test_7.png
# Generating predictions for image:  data/test_set_images/test_8/test_8.png
# Generating predictions for image:  data/test_set_images/test_9/test_9.png
# Generating predictions for image:  data/test_set_images/test_10/test_10.png
# Generating predictions for image:  data/test_set_images/test_11/test_11.png
# Generating predictions for image:  data/test_set_images/test_12/test_12.png
# Generating predictions for image:  data/test_set_images/test_13/test_13.png
# Generating predictions for image:  data/test_set_images/test_14/test_14.png
# Generating predictions for image:  data/test_set_images/test_15/test_15.png
# Generating predictions for image:  data/test_set_images/test_16/test_16.png
# Generating predictions for image:  data/test_set_images/test_17/test_17.png
# Generating predictions for image:  data/test_set_images/test_18/test_18.png
# Generating predictions for image:  data/test_set_images/test_19/test_19.png
# Generating predictions for image:  data/test_set_images/test_20/test_20.png
# Generating predictions for image:  data/test_set_images/test_21/test_21.png
# Generating predictions for image:  data/test_set_images/test_22/test_22.png
# Generating predictions for image:  data/test_set_images/test_23/test_23.png
# Generating predictions for image:  data/test_set_images/test_24/test_24.png
# Generating predictions for image:  data/test_set_images/test_25/test_25.png
# Generating predictions for image:  data/test_set_images/test_26/test_26.png
# Generating predictions for image:  data/test_set_images/test_27/test_27.png
# Generating predictions for image:  data/test_set_images/test_28/test_28.png
# Generating predictions for image:  data/test_set_images/test_29/test_29.png
# Generating predictions for image:  data/test_set_images/test_30/test_30.png
# Generating predictions for image:  data/test_set_images/test_31/test_31.png
# Generating predictions for image:  data/test_set_images/test_32/test_32.png
# Generating predictions for image:  data/test_set_images/test_33/test_33.png
# Generating predictions for image:  data/test_set_images/test_34/test_34.png
# Generating predictions for image:  data/test_set_images/test_35/test_35.png
# Generating predictions for image:  data/test_set_images/test_36/test_36.png
# Generating predictions for image:  data/test_set_images/test_37/test_37.png
# Generating predictions for image:  data/test_set_images/test_38/test_38.png
# Generating predictions for image:  data/test_set_images/test_39/test_39.png
# Generating predictions for image:  data/test_set_images/test_40/test_40.png
# Generating predictions for image:  data/test_set_images/test_41/test_41.png
# Generating predictions for image:  data/test_set_images/test_42/test_42.png
# Generating predictions for image:  data/test_set_images/test_43/test_43.png
# Generating predictions for image:  data/test_set_images/test_44/test_44.png
# Generating predictions for image:  data/test_set_images/test_45/test_45.png
# Generating predictions for image:  data/test_set_images/test_46/test_46.png
# Generating predictions for image:  data/test_set_images/test_47/test_47.png
# Generating predictions for image:  data/test_set_images/test_48/test_48.png
# Generating predictions for image:  data/test_set_images/test_49/test_49.png
# Generating predictions for image:  data/test_set_images/test_50/test_50.png
